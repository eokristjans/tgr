# %%
# See: https://stackoverflow.com/questions/53435352/animate-matplotlib-parametric-example
import matplotlib
matplotlib.use('Agg')
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from matplotlib import animation, rc
import matplotlib.pyplot as plt
import math
from celluloid import Camera

import functionsV2
import v2
plt.rcParams['legend.fontsize'] = 10
plt.xlabel('x', fontsize=10)
plt.ylabel('y', fontsize=10)
plt.rcParams.update({'figure.max_open_warning': 0})

# %%
figTStar = plt.figure()
figTStar.suptitle('$t*(s)$', fontsize=12)
axTStar = figTStar.gca()
axTStar.set_xlabel('x', fontsize=10)
axTStar.set_ylabel('y', fontsize=10)
axTStar.grid(b=True, axis='both')
axTStar.set_xticks(np.arange(0, 1.1, 0.1))
axTStar.set_yticks(np.arange(0, 1.7, 0.1))
ax
cameraTStar = Camera(figTStar)
x=[]
y=[]
r=[]
s=[]

# Prepare arrays r, s
for t in np.arange(0, 1, 0.01):
    r += [0.5 + t*(0.3 + 3.9*t - 4.7*t**2)]
    s += [1.5 + t*(0.3 + 0.9*t - 2.7*t**2)]

# Prepare arrays x, y and animate
for t in v2.tStarArray:
    x += [0.5 + t*(0.3 + 3.9*t - 4.7*t**2)]
    y += [1.5 + t*(0.3 + 0.9*t - 2.7*t**2)]
    axTStar.plot(r, s, color='red')
    axTStar.plot(x, y, 'bo', color='blue')
    cameraTStar.snap()
animTStar = cameraTStar.animate(blit=False, interval=100)
animTStar.save('tStar.mp4')

# %%
rc('animation', html='jshtml')
animTStar
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgffd0c53355b64ab2a8526675c43a55dc">
#     <br>
#     <input id="_anim_sliderffd0c53355b64ab2a8526675c43a55dc" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animffd0c53355b64ab2a8526675c43a55dc.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animffd0c53355b64ab2a8526675c43a55dc.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animffd0c53355b64ab2a8526675c43a55dc.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animffd0c53355b64ab2a8526675c43a55dc.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animffd0c53355b64ab2a8526675c43a55dc.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animffd0c53355b64ab2a8526675c43a55dc.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animffd0c53355b64ab2a8526675c43a55dc.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animffd0c53355b64ab2a8526675c43a55dc.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animffd0c53355b64ab2a8526675c43a55dc.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animffd0c53355b64ab2a8526675c43a55dc.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectffd0c53355b64ab2a8526675c43a55dc" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgffd0c53355b64ab2a8526675c43a55dc";
#     var slider_id = "_anim_sliderffd0c53355b64ab2a8526675c43a55dc";
#     var loop_select_id = "_anim_loop_selectffd0c53355b64ab2a8526675c43a55dc";
#     var frames = new Array(21);
#
#   frames[0] = "...\
# AAAPYQAAD2EBqD+naQAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvOIA7rQAAIABJREFUeJzs3XlcVXXi//HXBa4sGpriBqJom5qK\
# S6NZzaQlOliW7UWNhpNt2qj0S6VcoJoWm0ydr41tLtlQlrm0OClaauY2aqRlaYwUpYiaxRXIywXu\
# 748TlAGKcuBwz30/H4/zuJzDOYf3vaG9/ZzN4fV6vYiIiIiI3wiwOoCIiIiI1C0VQBERERE/owIo\
# IiIi4mdUAEVERET8jAqgiIiIiJ9RARQRERHxMyqAIiIiIn5GBVBERETEz6gAioiIiPgZFUARERER\
# P6MCKCIiIuJnVABFRIBp06bRsWNHSktLq73NnDlzaNu2LW63uxaTiYiYTwVQRHyK1+vl0Ucf5eOP\
# Pz7pemvXruXOO++s1j5dLhdPP/00EyZMICCg+n8t3nnnnRQVFfHCCy9UexsRkfpABVBEfMrevXuZ\
# OnUqOTk5Fb6Xl5fH5s2bKyz/6aef2LJlS5X7nDt3LsXFxdx2222nlSUkJIThw4czffp0vF7vaW0r\
# ImIlFUAR8Snbt28HoGfPnhW+9+233zJ8+HDGjBlDfn4+AG+//TY9e/Zk06ZNVe5z3rx5XHPNNYSE\
# hJx2nptvvplvv/2Wjz766LS3FRGxigqgiPiM3r17c/vttwNw3nnn4XA4aNKkSfn3u3Xrxq5du4iO\
# juaee+5h8eLFvPnmm3z00UeMHTu20n1mZWWxc+dOBgwYUOF72dnZ3HXXXXTo0IGQkBBatWrF4MGD\
# yczMLF+nV69eNG3alOXLl5v8bkVEak+Q1QFERKprwoQJpKSk4Ha7mTJlCsAJBRDA4XAQEBCAw+Eo\
# ny/7ujIbN24EKo4o5ubmctFFF9GsWTNGjhxJixYt+O6771i6dClBQSf+1dmzZ08++eSTGr8/EZG6\
# ogIoIj7jhhtuICkpiSuuuII77rijwvd37drFzTffTFxcHHPmzGHx4sVcffXV9OvXjzFjxjBmzJgK\
# 23z11VcAtG/f/oTlr732GseOHSMzM5Pw8PDy5SkpKRX20aFDBxYuXFjDdyciUnd0CFhEfEZeXh7Z\
# 2dl069at0u+3bduWefPmMWvWLBo1agTAjTfeyI4dO7j44osr3eaHH34gKCiofP0yP/30Ex6Phx07\
# dpwy19lnn83PP/9MYWHhab4jERFrqACKiM/YuXMnQJUFsHHjxpUWvSZNmtCnT5/T+lnDhg2jRYsW\
# 9O/fn169evHMM89UeuUxUH4F8MkONYuI1CcqgCLiM8oKYGxs7CnX7devH/Pnzz/les2aNaO4uJhj\
# x46dsPy8885j7969LFiwgA4dOjB58mTOP//8Ss/1+/HHHwkLCyM0NLR6b0RExGIqgCLiM3bu3Enr\
# 1q2JiIgwbZ8dO3YEjKuBf69Ro0YMGzaMt956i88++wy3282bb75ZYb2srCw6depkWiYRkdqmAigi\
# PiM7O5s2bdqYus++ffsCsG3btvJlR44cqbBeaGgoJSUlREZGVvjejh07uOSSS0zNJSJSm3QVsIj4\
# jPbt2/Phhx8ybdo0IiMj6dSpE7169arRPjt06ECXLl1YvXo1I0aMAOCBBx7g888/55prrqF9+/bk\
# 5OTw4osv0qZNG0aOHHnC9tu3b+fo0aNce+21NcohIlKXVABFxGdMmjSJffv28dhjj5Gfn8+sWbNq\
# XAABRowYwZQpU/j5558JDQ0lLi6OQ4cO8dJLL+FyuYiOjub6669n0qRJNG3a9IRt33rrLdq2bcsV\
# V1xR4xwiInXF4dUDLEXEz+Xl5dGhQwemTZvGX//612pv53a7iYmJYeLEiZXeY1BEpL7SOYAi4vca\
# N27M+PHjeeaZZygtLa32dvPmzcPpdHLvvffWYjoREfNpBFBERETEz2gEUERERMTP

# %%
figT = plt.figure()
figT.suptitle('$t=0.02$', fontsize=12)
axT = figT.gca()
axT.set_xlabel('x', fontsize=10)
axT.set_ylabel('y', fontsize=10)
axT.grid(b=True, axis='both')
axT.set_xticks(np.arange(0, 1.1, 0.1))
axT.set_yticks(np.arange(0, 1.7, 0.1))
cameraT = Camera(figT)

# Prepare arrays k, k
k = []
l = []

# Prepare arrays x, y and animate
for t in np.arange(0, 1, 0.02):
    k += [0.5 + t*(0.3 + 3.9*t - 4.7*t**2)]
    l += [1.5 + t*(0.3 + 0.9*t - 2.7*t**2)]
    axT.plot(r, s, color='red')
    axT.plot(k, l, 'bo', color='blue')
    cameraT.snap()
animT = cameraT.animate(blit=False, interval=100)
animT.save('t.mp4')
animT
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img3c45949cb8264ad68ef6f5dcf2f17f8f">
#     <br>
#     <input id="_anim_slider3c45949cb8264ad68ef6f5dcf2f17f8f" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim3c45949cb8264ad68ef6f5dcf2f17f8f.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim3c45949cb8264ad68ef6f5dcf2f17f8f.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim3c45949cb8264ad68ef6f5dcf2f17f8f.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim3c45949cb8264ad68ef6f5dcf2f17f8f.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim3c45949cb8264ad68ef6f5dcf2f17f8f.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim3c45949cb8264ad68ef6f5dcf2f17f8f.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim3c45949cb8264ad68ef6f5dcf2f17f8f.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim3c45949cb8264ad68ef6f5dcf2f17f8f.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim3c45949cb8264ad68ef6f5dcf2f17f8f.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim3c45949cb8264ad68ef6f5dcf2f17f8f.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select3c45949cb8264ad68ef6f5dcf2f17f8f" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img3c45949cb8264ad68ef6f5dcf2f17f8f";
#     var slider_id = "_anim_slider3c45949cb8264ad68ef6f5dcf2f17f8f";
#     var loop_select_id = "_anim_loop_select3c45949cb8264ad68ef6f5dcf2f17f8f";
#     var frames = new Array(50);
#
#   frames[0] = "...\
# AAAPYQAAD2EBqD+naQAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvOIA7rQAAIABJREFUeJzs